# %% [markdown]
# # 1

# %%
import pandas as pd

# 파일 경로
stock_path = "./AAPL_1hour_data_365days.csv"
news_path = "./apple_finbert_finnhub.csv"

# 데이터 불러오기
stock_df = pd.read_csv(stock_path, parse_dates=["Datetime"])
news_df = pd.read_csv(news_path, parse_dates=["pubDate"])

# 타임존 제거
stock_df["Datetime"] = stock_df["Datetime"].dt.tz_localize(None)
news_df["pubDate"] = news_df["pubDate"].dt.tz_localize(None)

# 정렬
stock_df = stock_df.sort_values("Datetime").reset_index(drop=True)

# 제외할 열
exclude_cols = ['Is_Trading_Hours', 'Is_Market_Open', 'Is_Premarket', 'Is_Aftermarket', 'Is_Extended_Hours']
stock_df = stock_df.drop(columns=[col for col in exclude_cols if col in stock_df.columns])

# 병합 결과
rows = []

for _, news_row in news_df.iterrows():
    news_time = news_row['pubDate']

    # 뉴스 이후 가장 가까운 주가
    future_stock = stock_df[stock_df['Datetime'] > news_time].head(1)
    if future_stock.empty:
        continue

    target_row = future_stock.iloc[0]
    target_time = target_row['Datetime']
    target_close = target_row['Close']

    # 과거 3개 주가
    past_rows = stock_df[stock_df['Datetime'] < target_time].tail(3)
    if len(past_rows) < 3:
        continue

    past_last_close = past_rows.iloc[-1]['Close']

    # 상승률
    return_pct = (target_close - past_last_close) / past_last_close * 100
    label = 1 if return_pct >= 0.4 else (-1 if return_pct <= -0.4 else 0)

    # 병합 row 생성
    row = {
        "news_id": news_row['id'],
        "news_time": news_time,
        "target_close": target_close,
        "target_return_pct": return_pct,
        "target_multi_raw": label,
        "finbert_positive": news_row['finbert_positive'],
        "finbert_neutral": news_row['finbert_neutral'],
        "finbert_negative": news_row['finbert_negative'],
    }

    # 과거 3개 flatten
    for i, (_, stock_row) in enumerate(past_rows.iterrows(), 1):
        for col in stock_df.columns:
            if col == "Datetime":
                continue
            row[f"x{i}_{col}"] = stock_row[col]

    rows.append(row)

# 최종 DataFrame
merged_df = pd.DataFrame(rows)

# 클래스 0/1/2로 매핑 (XGBoost용)
label_map = {-1: 0, 0: 1, 1: 2}
merged_df["target_multi"] = merged_df["target_multi_raw"].map(label_map)

# 저장
merged_df.to_csv("news_stock_classification.csv", index=False)
print("✅ 병합 완료: news_stock_classification.csv 저장됨")
# Out:
# ✅ 병합 완료: news_stock_classification.csv 저장됨

# %%
import pandas as pd
import numpy as np
import torch
from torch import nn
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# 1. 데이터 불러오기
df = pd.read_csv("news_stock_classification.csv", parse_dates=["news_time"])

# 2. Feature 및 Label 준비
feature_cols = [col for col in df.columns if col.startswith("x") or col.startswith("finbert_")]
X = df[feature_cols].fillna(0)
y = df["target_multi"]

# 3. 시계열 데이터 3-step 생성 (x1_, x2_, x3_)
X_seq = []
for i in range(len(X)):
    X_seq.append([
        X.iloc[i][[col for col in X.columns if col.startswith("x1_")]].values,
        X.iloc[i][[col for col in X.columns if col.startswith("x2_")]].values,
        X.iloc[i][[col for col in X.columns if col.startswith("x3_")]].values
    ])
X_seq = np.array(X_seq)

# 4. FinBERT 피처 추가 (Broadcast across time steps)
finbert_feats = X[[c for c in X.columns if c.startswith("finbert_")]].values
finbert_feats = np.repeat(finbert_feats[:, np.newaxis, :], 3, axis=1)
X_seq = np.concatenate([X_seq, finbert_feats], axis=-1)

# 5. 정규화
n_samples, time_steps, n_features = X_seq.shape
X_reshaped = X_seq.reshape(-1, n_features)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_reshaped)
X_seq = X_scaled.reshape(n_samples, time_steps, n_features)

# 6. Tensor로 변환
X_tensor = torch.tensor(X_seq, dtype=torch.float32)
y_tensor = torch.tensor(y.values, dtype=torch.long)

# 7. Train/Test 분리
X_train, X_test, y_train, y_test = train_test_split(X_tensor, y_tensor, test_size=0.2, shuffle=False)
train_dl = DataLoader(TensorDataset(X_train, y_train), batch_size=32, shuffle=True)
test_dl = DataLoader(TensorDataset(X_test, y_test), batch_size=32)

# 8. LSTM 모델 정의
class LSTMClassifier(nn.Module):
    def __init__(self, input_dim, hidden_dim=64, output_dim=3):
        super().__init__()
        self.lstm = nn.LSTM(input_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        _, (hn, _) = self.lstm(x)
        return self.fc(hn[-1])

# 9. 학습 설정
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = LSTMClassifier(input_dim=n_features).to(device)
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# 10. 학습 루프
for epoch in range(50):
    model.train()
    total_loss = 0
    for xb, yb in train_dl:
        xb, yb = xb.to(device), yb.to(device)
        pred = model(xb)
        loss = loss_fn(pred, yb)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    print(f"Epoch {epoch+1} | Loss: {total_loss:.4f}")
# Out:
# Epoch 1 | Loss: 164.0788
# Epoch 2 | Loss: 141.5729
# Epoch 3 | Loss: 125.2798
# Epoch 4 | Loss: 111.2254
# Epoch 5 | Loss: 99.4632
# Epoch 6 | Loss: 90.4368
# Epoch 7 | Loss: 81.4495
# Epoch 8 | Loss: 72.8773
# Epoch 9 | Loss: 67.3597
# Epoch 10 | Loss: 60.8399
# Epoch 11 | Loss: 55.6103
# Epoch 12 | Loss: 51.2171
# Epoch 13 | Loss: 46.9381
# Epoch 14 | Loss: 42.8304
# Epoch 15 | Loss: 39.2854
# Epoch 16 | Loss: 36.0406
# Epoch 17 | Loss: 32.5115
# Epoch 18 | Loss: 29.6463
# Epoch 19 | Loss: 27.1152
# Epoch 20 | Loss: 24.6855
# Epoch 21 | Loss: 23.1054
# Epoch 22 | Loss: 20.5943
# Epoch 23 | Loss: 18.8145
# Epoch 24 | Loss: 17.1873
# Epoch 25 | Loss: 15.4179
# Epoch 26 | Loss: 14.2074
# Epoch 27 | Loss: 12.4770
# Epoch 28 | Loss: 11.9293
# Epoch 29 | Loss: 10.3284
# Epoch 30 | Loss: 9.1492
# Epoch 31 | Loss: 8.0573
# Epoch 32 | Loss: 7.6288
# Epoch 33 | Loss: 6.4673
# Epoch 34 | Loss: 5.7015
# Epoch 35 | Loss: 5.3819
# Epoch 36 | Loss: 5.4640
# Epoch 37 | Loss: 4.4068
# Epoch 38 | Loss: 5.6787
# Epoch 39 | Loss: 3.5228
# Epoch 40 | Loss: 2.8861
# Epoch 41 | Loss: 2.5120
# Epoch 42 | Loss: 2.3651
# Epoch 43 | Loss: 2.1326
# Epoch 44 | Loss: 1.7234
# Epoch 45 | Loss: 1.7642
# Epoch 46 | Loss: 2.6554
# Epoch 47 | Loss: 1.8456
# Epoch 48 | Loss: 1.2135
# Epoch 49 | Loss: 1.0162
# Epoch 50 | Loss: 1.0091
#
# 📈 Accuracy: 0.5701805474665114
#
# 📊 Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.10      0.13      0.12       246
#            1       0.75      0.75      0.75      1224
#            2       0.19      0.14      0.16       247
#
#     accuracy                           0.57      1717
#    macro avg       0.35      0.34      0.34      1717
# weighted avg       0.58      0.57      0.57      1717
#
#
# 🧱 Confusion Matrix:
#  [[ 33 136  77]
#  [244 912  68]
#  [ 46 167  34]]

# %%
# 11. 평가
model.eval()
all_preds, all_labels = [], []
with torch.no_grad():
    for xb, yb in test_dl:
        xb = xb.to(device)
        preds = model(xb).argmax(dim=1).cpu().numpy()
        all_preds.extend(preds)
        all_labels.extend(yb.numpy())

print("\n📈 Accuracy:", accuracy_score(all_labels, all_preds))
print("\n📊 Classification Report:\n", classification_report(all_labels, all_preds))
print("\n🧱 Confusion Matrix:\n", confusion_matrix(all_labels, all_preds))
# Out:
# 📈 Accuracy: 0.5701805474665114
#
# 📊 Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.10      0.13      0.12       246
#            1       0.75      0.75      0.75      1224
#            2       0.19      0.14      0.16       247
#
#     accuracy                           0.57      1717
#    macro avg       0.35      0.34      0.34      1717
# weighted avg       0.58      0.57      0.57      1717
#
#
# 🧱 Confusion Matrix:
#  [[ 33 136  77]
#  [244 912  68]
#  [ 46 167  34]]

# %% [markdown]
# # 2

# %%
import pandas as pd
import os

def load_stock_and_news(stock_path, news_path):
    stock = pd.read_csv(stock_path, parse_dates=["Datetime"])
    news = pd.read_csv(news_path, parse_dates=["pubDate"])

    stock["Datetime"] = stock["Datetime"].dt.tz_localize(None)
    news["pubDate"] = news["pubDate"].dt.tz_localize(None)

    # 정렬 및 제외 열 제거
    stock = stock.sort_values("Datetime").reset_index(drop=True)
    stock = stock.drop(columns=[col for col in stock.columns if col.startswith("Is_")])

    return stock, news


def make_binary_merged_df(stock_df, news_df, company):
    rows = []

    for _, news_row in news_df.iterrows():
        news_time = news_row["pubDate"]

        # 뉴스 이후 가장 가까운 주가
        future_row = stock_df[stock_df["Datetime"] > news_time].head(1)
        if future_row.empty:
            continue

        target_row = future_row.iloc[0]
        target_return = target_row.get("Returns", None)
        if pd.isna(target_return):
            continue

        # 과거 5개
        past_rows = stock_df[stock_df["Datetime"] < target_row["Datetime"]].tail(5)
        if len(past_rows) < 5:
            continue

        if target_return >= 0.01:
            label = 1
        elif target_return <= -0.01:
            label = 0
        else:
            continue  # 기준 미달인 경우는 무시

        row = {
            "company": company,
            "news_time": news_time,
            "target_return": target_return,
            "target": label,
            "finbert_positive": news_row["finbert_positive"],
            "finbert_neutral": news_row["finbert_neutral"],
            "finbert_negative": news_row["finbert_negative"]
        }

        for i, (_, p_row) in enumerate(past_rows.iterrows(), 1):
            for col in stock_df.columns:
                if col == "Datetime":
                    continue
                row[f"x{i}_{col}"] = p_row[col]

        rows.append(row)

    return pd.DataFrame(rows)

# %%
base_dir = "./"  # 압축 풀린 폴더 기준
companies = {
    "AAPL": ("AAPL_1hour_data_365days.csv", "apple_finbert_finnhub.csv"),
    "AMZN": ("AMZN_1hour_data_365days.csv", "amazon_finbert_finnhub.csv"),
    "GOOGL": ("GOOGL_1hour_data_365days.csv", "google_finbert_finnhub.csv"),
    "MSFT": ("MSFT_1hour_data_365days.csv", "microsoft_finbert_finnhub.csv"),
    "TSLA": ("TSLA_1hour_data_365days.csv", "tesla_finbert_finnhub.csv"),
}

dfs = []
for company, (stock_file, news_file) in companies.items():
    stock_path = os.path.join(base_dir, stock_file)
    news_path = os.path.join(base_dir, news_file)
    if not os.path.exists(stock_path) or not os.path.exists(news_path):
        continue

    stock_df, news_df = load_stock_and_news(stock_path, news_path)
    merged_df = make_binary_merged_df(stock_df, news_df, company)
    dfs.append(merged_df)

# 최종 병합
final_df = pd.concat(dfs, ignore_index=True)
final_df.to_csv("news_stock_binary_classification.csv", index=False)
print("news_stock_binary_classification.csv 저장 완료")
# Out:
# news_stock_binary_classification.csv 저장 완료

# %%
import pandas as pd
import numpy as np
import torch
from torch import nn
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# 1. Load data
df = pd.read_csv("news_stock_binary_classification.csv", parse_dates=["news_time"])
df = df.dropna()

# 2. Features & Labels
feature_cols = [col for col in df.columns if col.startswith("x") or col.startswith("finbert_")]
X = df[feature_cols].fillna(0)
y = df["target"]

# 3. Reshape to time-series: x1_ ~ x5_
X_seq = []
for i in range(len(X)):
    timestep_data = []
    for t in range(1, 6):
        timestep_data.append(X.iloc[i][[col for col in X.columns if col.startswith(f"x{t}_")]].values)
    X_seq.append(timestep_data)
X_seq = np.array(X_seq)

# 4. FinBERT features broadcast
finbert_feats = X[[c for c in X.columns if c.startswith("finbert_")]].values
finbert_feats = np.repeat(finbert_feats[:, np.newaxis, :], 5, axis=1)
X_seq = np.concatenate([X_seq, finbert_feats], axis=-1)

# 5. Normalize
n_samples, time_steps, n_features = X_seq.shape
X_reshaped = X_seq.reshape(-1, n_features)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_reshaped)
X_seq = X_scaled.reshape(n_samples, time_steps, n_features)

# 6. Tensor conversion
X_tensor = torch.tensor(X_seq, dtype=torch.float32)
y_tensor = torch.tensor(y.values, dtype=torch.long)

# 7. Time-based split
split_idx = int(len(df) * 0.8)
X_train, X_test = X_tensor[:split_idx], X_tensor[split_idx:]
y_train, y_test = y_tensor[:split_idx], y_tensor[split_idx:]

train_dl = DataLoader(TensorDataset(X_train, y_train), batch_size=32, shuffle=True)
test_dl  = DataLoader(TensorDataset(X_test, y_test), batch_size=32)

# 8. Model - Deep LSTM + MLP
class DeepLSTMClassifier(nn.Module):
    def __init__(self, input_dim, lstm_hidden=512, mlp_hidden=[512, 256, 128, 64], output_dim=2):
        super().__init__()
        self.lstm = nn.LSTM(input_dim, lstm_hidden, num_layers=2, batch_first=True, dropout=0.3)
        self.mlp = nn.Sequential(
            nn.Linear(lstm_hidden, mlp_hidden[0]),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(mlp_hidden[0], mlp_hidden[1]),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(mlp_hidden[1], mlp_hidden[2]),
            nn.ReLU(),
            nn.Linear(mlp_hidden[2], mlp_hidden[3]),
            nn.ReLU(),
            nn.Linear(mlp_hidden[3], output_dim)
        )

    def forward(self, x):
        _, (hn, _) = self.lstm(x)
        return self.mlp(hn[-1])

# 9. Focal Loss 정의
class FocalLoss(nn.Module):
    def __init__(self, gamma=2.0, alpha=0.8):
        super().__init__()
        self.gamma = gamma
        self.alpha = alpha

    def forward(self, inputs, targets):
        ce_loss = nn.CrossEntropyLoss(reduction='none')(inputs, targets)
        pt = torch.exp(-ce_loss)
        focal = self.alpha * (1 - pt) ** self.gamma * ce_loss
        return focal.mean()

# 10. Training Setup + EarlyStopping
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = DeepLSTMClassifier(input_dim=n_features).to(device)

loss_fn = FocalLoss(gamma=2.0, alpha=2.0)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
patience = 12
best_loss = float("inf")
epochs_no_improve = 0

for epoch in range(100):
    model.train()
    total_loss = 0
    for xb, yb in train_dl:
        xb, yb = xb.to(device), yb.to(device)
        pred = model(xb)
        loss = loss_fn(pred, yb)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    # Validation loss
    val_loss = 0
    model.eval()
    with torch.no_grad():
        for xb, yb in test_dl:
            xb, yb = xb.to(device), yb.to(device)
            pred = model(xb)
            loss = loss_fn(pred, yb)
            val_loss += loss.item()
    val_loss /= len(test_dl)

    print(f"Epoch {epoch+1:02d} | Train Loss: {total_loss:.4f} | Val Loss: {val_loss:.4f}")

    if val_loss < best_loss:
        best_loss = val_loss
        epochs_no_improve = 0
        best_model_state = model.state_dict()
    else:
        epochs_no_improve += 1
        if epochs_no_improve >= patience:
            print("⏹️ Early stopping triggered.")
            break

model.load_state_dict(best_model_state)

# 11. 평가
model.eval()
all_preds, all_labels = [], []
with torch.no_grad():
    for xb, yb in test_dl:
        xb = xb.to(device)
        preds = model(xb).argmax(dim=1).cpu().numpy()
        all_preds.extend(preds)
        all_labels.extend(yb.numpy())

print("\n📈 Accuracy:", accuracy_score(all_labels, all_preds))
print("\n📊 Classification Report:\n", classification_report(all_labels, all_preds))
print("\n🧱 Confusion Matrix:\n", confusion_matrix(all_labels, all_preds))
# Out:
# Epoch 01 | Train Loss: 41.3100 | Val Loss: 0.3419
# Epoch 02 | Train Loss: 37.3130 | Val Loss: 0.4158
# Epoch 03 | Train Loss: 32.4232 | Val Loss: 0.7833
# Epoch 04 | Train Loss: 28.6629 | Val Loss: 0.7505
# Epoch 05 | Train Loss: 22.6333 | Val Loss: 1.1208
# Epoch 06 | Train Loss: 22.0089 | Val Loss: 0.9983
# Epoch 07 | Train Loss: 17.0868 | Val Loss: 1.4601
# Epoch 08 | Train Loss: 14.0339 | Val Loss: 2.3823
# Epoch 09 | Train Loss: 14.4976 | Val Loss: 1.4230
# Epoch 10 | Train Loss: 12.8186 | Val Loss: 1.4774
# Epoch 11 | Train Loss: 9.4039 | Val Loss: 2.5632
# Epoch 12 | Train Loss: 7.7556 | Val Loss: 2.0023
# Epoch 13 | Train Loss: 6.9513 | Val Loss: 3.5774
# ⏹️ Early stopping triggered.
#
# 📈 Accuracy: 0.5678137651821862
#
# 📊 Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.53      0.47      0.50       449
#            1       0.59      0.65      0.62       539
#
#     accuracy                           0.57       988
#    macro avg       0.56      0.56      0.56       988
# weighted avg       0.56      0.57      0.56       988
#
#
# 🧱 Confusion Matrix:
#  [[210 239]
#  [188 351]]

# %% [markdown]
# # 3

# %%
import pandas as pd
import numpy as np
import os

def load_stock_and_news(stock_path, news_path):
    stock = pd.read_csv(stock_path, parse_dates=["Datetime"])
    news = pd.read_csv(news_path, parse_dates=["pubDate"])

    stock["Datetime"] = stock["Datetime"].dt.tz_localize(None)
    news["pubDate"] = news["pubDate"].dt.tz_localize(None)

    stock = stock.sort_values("Datetime").reset_index(drop=True)
    stock = stock.drop(columns=[col for col in stock.columns if col.startswith("Is_")])

    return stock, news

def classify_context(timestamp):
    hour, minute = timestamp.hour, timestamp.minute
    if hour < 9 or (hour == 9 and minute < 30):
        return "premarket"
    elif 9 <= hour < 16:
        return "intraday"
    else:
        return "aftermarket"

def make_binary_merged_df(stock_df, news_df, company):
    rows = []

    for _, news_row in news_df.iterrows():
        news_time = news_row["pubDate"]
        context = classify_context(news_time)

        future_row = stock_df[stock_df["Datetime"] > news_time].head(1)
        if future_row.empty:
            continue

        target_row = future_row.iloc[0]
        target_return = target_row.get("Returns", None)
        if pd.isna(target_return):
            continue

        past_rows = stock_df[stock_df["Datetime"] < target_row["Datetime"]].tail(5)
        if len(past_rows) < 5:
            continue

        if target_return >= 0.01:
            label = 1
        elif target_return <= -0.01:
            label = 0
        else:
            continue

        row = {
            "company": company,
            "news_time": news_time,
            "context": context,
            "target_return": target_return,
            "target": label,
            "finbert_positive": news_row["finbert_positive"],
            "finbert_neutral": news_row["finbert_neutral"],
            "finbert_negative": news_row["finbert_negative"]
        }

        for i, (_, p_row) in enumerate(past_rows.iterrows(), 1):
            for col in stock_df.columns:
                if col == "Datetime":
                    continue
                row[f"x{i}_{col}"] = p_row[col]

        rows.append(row)

    return pd.DataFrame(rows)

# %%
base_dir = "./"
companies = {
    "AAPL": ("AAPL_1hour_data_365days.csv", "apple_finbert_finnhub.csv"),
    "AMZN": ("AMZN_1hour_data_365days.csv", "amazon_finbert_finnhub.csv"),
    "GOOGL": ("GOOGL_1hour_data_365days.csv", "google_finbert_finnhub.csv"),
    "MSFT": ("MSFT_1hour_data_365days.csv", "microsoft_finbert_finnhub.csv"),
    "TSLA": ("TSLA_1hour_data_365days.csv", "tesla_finbert_finnhub.csv"),
}

dfs = []
for company, (stock_file, news_file) in companies.items():
    stock_path = os.path.join(base_dir, stock_file)
    news_path = os.path.join(base_dir, news_file)
    if not os.path.exists(stock_path) or not os.path.exists(news_path):
        continue

    stock_df, news_df = load_stock_and_news(stock_path, news_path)
    merged_df = make_binary_merged_df(stock_df, news_df, company)
    dfs.append(merged_df)

final_df = pd.concat(dfs, ignore_index=True)
final_df.to_csv("news_stock_binary_classification.csv", index=False)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Concatenate

# 1. 데이터 로드
df = pd.read_csv("news_stock_binary_classification.csv", parse_dates=["news_time"])
df["context"] = df["context"].astype(str)
df["company"] = df["company"].astype(str)

# 2. 입력 분리
feature_cols_seq = [col for col in df.columns if col.startswith("x")]
feature_cols_finbert = ["finbert_positive", "finbert_neutral", "finbert_negative"]
company_dummies = pd.get_dummies(df["company"], prefix="company")
context_dummies = pd.get_dummies(df["context"], prefix="context")
X_static = pd.concat([df[feature_cols_finbert], company_dummies, context_dummies], axis=1).astype(np.float32).values
X_seq = df[feature_cols_seq].values
y = df["target"].values

# 3. LSTM 시퀀스 리쉐이핑
X_seq = X_seq.reshape((-1, 5, len(feature_cols_seq)//5))

# 4. 시계열 스케일링
scaler = StandardScaler()
X_seq_scaled = scaler.fit_transform(X_seq.reshape(-1, X_seq.shape[-1])).reshape(X_seq.shape)

# 5. TimeSeriesSplit 적용
tscv = TimeSeriesSplit(n_splits=5)

for fold, (train_idx, test_idx) in enumerate(tscv.split(X_seq_scaled), 1):
    X_train_seq = X_seq_scaled[train_idx]
    X_test_seq = X_seq_scaled[test_idx]
    X_train_static = X_static[train_idx]
    X_test_static = X_static[test_idx]
    y_train = y[train_idx]
    y_test = y[test_idx]

    # 모델 정의
    tf.keras.backend.clear_session()
    np.random.seed(42)
    tf.random.set_seed(42)

    seq_input = Input(shape=(5, X_seq.shape[2]), name="seq_input")
    lstm_out = LSTM(64, activation="tanh")(seq_input)

    static_input = Input(shape=(X_static.shape[1],), name="static_input")
    x = Concatenate()([lstm_out, static_input])
    x = Dense(64, activation="relu")(x)
    x = Dense(32, activation="relu")(x)
    output = Dense(1, activation="sigmoid")(x)

    model = Model(inputs=[seq_input, static_input], outputs=output)
    model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

    # 학습
    model.fit([X_train_seq, X_train_static], y_train, epochs=50, batch_size=32, verbose=1)

    # 예측
    y_prob = model.predict([X_test_seq, X_test_static])
    y_pred = (y_prob.flatten() > 0.5).astype(int)

    # 출력
    print(f"\n📦 Fold {fold}")
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
    print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# WARNING:tensorflow:From C:\Users\jhh33\anaconda3\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Epoch 1/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5527 - loss: 0.6813
# Epoch 2/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7880 - loss: 0.5674
# Epoch 3/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8538 - loss: 0.3556
# Epoch 4/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9095 - loss: 0.2548
# Epoch 5/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9170 - loss: 0.2023
# Epoch 6/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9374 - loss: 0.1643
# Epoch 7/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9453 - loss: 0.1348
# Epoch 8/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9616 - loss: 0.1085
# Epoch 9/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9649 - loss: 0.0853
# Epoch 10/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9673 - loss: 0.0724
# Epoch 11/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9797 - loss: 0.0604
# Epoch 12/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9800 - loss: 0.0495
# Epoch 13/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9874 - loss: 0.0349
# Epoch 14/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9939 - loss: 0.0279
# Epoch 15/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9922 - loss: 0.0276
# Epoch 16/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9844 - loss: 0.0272
# Epoch 17/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9863 - loss: 0.0422
# Epoch 18/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9870 - loss: 0.0227
# Epoch 19/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9943 - loss: 0.0160
# Epoch 20/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9977 - loss: 0.0092
# Epoch 21/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9977 - loss: 0.0077
# Epoch 22/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9977 - loss: 0.0063
# Epoch 23/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9977 - loss: 0.0052
# Epoch 24/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9989 - loss: 0.0042
# Epoch 25/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0035
# Epoch 26/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0033
# Epoch 27/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0027
# Epoch 28/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0025
# Epoch 29/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 30/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 31/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 32/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0013
# Epoch 33/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0011
# Epoch 34/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0010
# Epoch 35/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 8.8991e-04
# Epoch 36/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 7.9540e-04
# Epoch 37/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 7.4269e-04
# Epoch 38/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 6.5776e-04
# Epoch 39/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 6.1374e-04
# Epoch 40/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 5.4647e-04
# Epoch 41/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 5.1716e-04
# Epoch 42/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 4.6663e-04
# Epoch 43/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 4.3632e-04
# Epoch 44/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 4.0134e-04
# Epoch 45/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 3.7791e-04
# Epoch 46/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 3.4715e-04
# Epoch 47/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 3.3306e-04
# Epoch 48/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 3.0135e-04
# Epoch 49/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 2.8920e-04
# Epoch 50/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 2.6866e-04
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#
# 📦 Fold 1
# Accuracy: 0.5400485436893204
# Confusion Matrix:
#  [[178 261]
#  [118 267]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.60      0.41      0.48       439
#            1       0.51      0.69      0.58       385
#
#     accuracy                           0.54       824
#    macro avg       0.55      0.55      0.53       824
# weighted avg       0.56      0.54      0.53       824
#
# Epoch 1/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5922 - loss: 0.6743
# Epoch 2/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7823 - loss: 0.5352
# Epoch 3/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8612 - loss: 0.3689
# Epoch 4/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8908 - loss: 0.2674
# Epoch 5/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9117 - loss: 0.2121
# Epoch 6/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9302 - loss: 0.1678
# Epoch 7/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9510 - loss: 0.1320
# Epoch 8/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9645 - loss: 0.1077
# Epoch 9/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9698 - loss: 0.0851
# Epoch 10/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9720 - loss: 0.0787
# Epoch 11/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9677 - loss: 0.0831
# Epoch 12/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9809 - loss: 0.0634
# Epoch 13/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9900 - loss: 0.0440
# Epoch 14/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9893 - loss: 0.0362
# Epoch 15/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9901 - loss: 0.0326
# Epoch 16/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9887 - loss: 0.0337
# Epoch 17/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9946 - loss: 0.0199
# Epoch 18/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9955 - loss: 0.0155
# Epoch 19/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9978 - loss: 0.0124
# Epoch 20/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9883 - loss: 0.0331
# Epoch 21/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9824 - loss: 0.0444
# Epoch 22/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9940 - loss: 0.0231
# Epoch 23/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9977 - loss: 0.0130
# Epoch 24/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9985 - loss: 0.0056
# Epoch 25/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0035
# Epoch 26/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 27/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 28/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 29/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 30/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 31/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0011
# Epoch 32/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 9.9210e-04
# Epoch 33/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 8.4182e-04
# Epoch 34/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 7.6790e-04
# Epoch 35/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 6.6660e-04
# Epoch 36/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 6.0925e-04
# Epoch 37/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 5.4299e-04
# Epoch 38/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 4.9920e-04
# Epoch 39/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 4.5340e-04
# Epoch 40/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 4.2149e-04
# Epoch 41/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 3.8010e-04
# Epoch 42/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 3.5055e-04
# Epoch 43/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 3.2335e-04
# Epoch 44/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 2.9840e-04
# Epoch 45/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 2.7784e-04
# Epoch 46/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 2.5765e-04
# Epoch 47/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 2.4179e-04
# Epoch 48/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 2.2485e-04
# Epoch 49/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 2.1122e-04
# Epoch 50/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 1.9733e-04
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#
# 📦 Fold 2
# Accuracy: 0.5983009708737864
# Confusion Matrix:
#  [[367  49]
#  [282 126]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.57      0.88      0.69       416
#            1       0.72      0.31      0.43       408
#
#     accuracy                           0.60       824
#    macro avg       0.64      0.60      0.56       824
# weighted avg       0.64      0.60      0.56       824
#
# Epoch 1/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5554 - loss: 0.6789
# Epoch 2/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6932
# Epoch 3/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6933
# Epoch 4/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6933
# Epoch 5/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6933
# Epoch 6/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 7/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 8/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 9/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 10/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 11/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 12/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 13/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 14/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 15/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 16/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 17/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 18/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 19/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 20/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 21/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 22/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 23/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 24/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 25/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 26/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 27/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 28/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 29/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 30/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 31/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 32/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 33/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 34/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 35/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 36/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 37/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 38/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 39/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 40/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 41/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 42/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 43/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 44/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 45/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 46/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 47/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 48/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 49/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# Epoch 50/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5063 - loss: 0.6934
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#
# 📦 Fold 3
# Accuracy: 0.5533980582524272
# Confusion Matrix:
#  [[456   0]
#  [368   0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.55      1.00      0.71       456
#            1       0.00      0.00      0.00       368
#
#     accuracy                           0.55       824
#    macro avg       0.28      0.50      0.36       824
# weighted avg       0.31      0.55      0.39       824
# C:\Users\jhh33\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\jhh33\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\jhh33\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 1/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5480 - loss: 0.6853
# Epoch 2/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6913
# Epoch 3/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6906
# Epoch 4/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6905
# Epoch 5/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6905
# Epoch 6/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6905
# Epoch 7/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6905
# Epoch 8/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6905
# Epoch 9/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6905
# Epoch 10/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6905
# Epoch 11/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6905
# Epoch 12/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6905
# Epoch 13/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6905
# Epoch 14/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6905
# Epoch 15/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6905
# Epoch 16/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6904
# Epoch 17/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6904
# Epoch 18/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6904
# Epoch 19/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6904
# Epoch 20/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6904
# Epoch 21/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6904
# Epoch 22/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6904
# Epoch 23/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6904
# Epoch 24/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6904
# Epoch 25/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5430 - loss: 0.6904
# Epoch 26/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6904
# Epoch 27/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6904
# Epoch 28/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6904
# Epoch 29/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6904
# Epoch 30/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6904
# Epoch 31/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6904
# Epoch 32/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6904
# Epoch 33/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6904
# Epoch 34/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6904
# Epoch 35/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6904
# Epoch 36/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6904
# Epoch 37/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6904
# Epoch 38/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6904
# Epoch 39/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6904
# Epoch 40/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6904
# Epoch 41/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6904
# Epoch 42/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6904
# Epoch 43/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6904
# Epoch 44/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6904
# Epoch 45/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6904
# Epoch 46/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6904
# Epoch 47/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5430 - loss: 0.6904
# Epoch 48/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6904
# Epoch 49/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6904
# Epoch 50/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5430 - loss: 0.6904
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#
# 📦 Fold 4
# Accuracy: 0.3580097087378641
# Confusion Matrix:
#  [[295   0]
#  [529   0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.36      1.00      0.53       295
#            1       0.00      0.00      0.00       529
#
#     accuracy                           0.36       824
#    macro avg       0.18      0.50      0.26       824
# weighted avg       0.13      0.36      0.19       824
# C:\Users\jhh33\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\jhh33\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\jhh33\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 1/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.4961 - loss: 0.6934
# Epoch 2/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6929
# Epoch 3/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6929
# Epoch 4/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 5/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 6/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 7/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 8/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 9/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 10/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 11/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 12/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 13/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 14/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 15/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 16/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 17/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 18/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 19/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 20/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 21/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 22/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 23/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 24/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 25/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 26/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 27/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 28/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 29/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 30/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 31/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 32/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 33/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 34/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 35/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 36/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 37/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 38/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 39/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 40/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 41/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 42/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 43/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 44/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 45/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 46/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 47/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 48/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 49/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# Epoch 50/50
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5157 - loss: 0.6928
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#
# 📦 Fold 5
# Accuracy: 0.5097087378640777
# Confusion Matrix:
#  [[  0 404]
#  [  0 420]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       404
#            1       0.51      1.00      0.68       420
#
#     accuracy                           0.51       824
#    macro avg       0.25      0.50      0.34       824
# weighted avg       0.26      0.51      0.34       824
# C:\Users\jhh33\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\jhh33\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\jhh33\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import pandas as pd
import numpy as np
import torch
from torch import nn
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# 1. Load data
base_df = pd.read_csv("news_stock_binary_classification.csv", parse_dates=["news_time"])
base_df = base_df.dropna().reset_index(drop=True)

# 2. Extract FinBERT, Time Context, Company info
finbert_cols = [c for c in base_df.columns if c.startswith("finbert_")]

context_dummies = pd.get_dummies(base_df["context"], prefix="context")
company_dummies = pd.get_dummies(base_df["company"], prefix="company")

static_feats = pd.concat([
    base_df[finbert_cols],
    context_dummies,
    company_dummies
], axis=1).astype(np.float32)

# 3. Extract and reshape sequence features (x1_~x5_)
x_cols = [c for c in base_df.columns if c.startswith("x") and not c.startswith("x_")]
X_seq = []
for i in range(len(base_df)):
    timestep_data = []
    for t in range(1, 6):
        timestep_data.append(base_df.iloc[i][[col for col in x_cols if col.startswith(f"x{t}_")]].values)
    X_seq.append(timestep_data)
X_seq = np.array(X_seq, dtype=np.float32)  # (n_samples, 5, num_features_per_time)

# 4. Normalize sequence part
n_samples, time_steps, n_features = X_seq.shape
scaler = StandardScaler()
X_seq_reshaped = X_seq.reshape(-1, n_features)
X_seq_scaled = scaler.fit_transform(X_seq_reshaped).reshape(n_samples, time_steps, n_features)

# 5. Concatenate static features to each timestep
finbert_feats = static_feats.values[:, np.newaxis, :].repeat(time_steps, axis=1)
X_combined = np.concatenate([X_seq_scaled, finbert_feats], axis=-1)

# 6. Labels
y = base_df["target"].values

# 7. Tensor conversion
X_tensor = torch.tensor(X_combined, dtype=torch.float32)
y_tensor = torch.tensor(y, dtype=torch.long)

# 8. Time-based split
split_idx = int(len(base_df) * 0.8)
X_train, X_test = X_tensor[:split_idx], X_tensor[split_idx:]
y_train, y_test = y_tensor[:split_idx], y_tensor[split_idx:]

train_dl = DataLoader(TensorDataset(X_train, y_train), batch_size=32, shuffle=True)
test_dl  = DataLoader(TensorDataset(X_test, y_test), batch_size=32)

# 9. Model
class DeepLSTMClassifier(nn.Module):
    def __init__(self, input_dim, lstm_hidden=128, mlp_hidden=[128, 64], output_dim=2):
        super().__init__()
        self.lstm = nn.LSTM(input_dim, lstm_hidden, num_layers=1, batch_first=True, dropout=0.2)
        self.mlp = nn.Sequential(
            nn.Linear(lstm_hidden, mlp_hidden[0]),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(mlp_hidden[0], mlp_hidden[1]),
            nn.ReLU(),
            nn.Linear(mlp_hidden[1], output_dim)
        )

    def forward(self, x):
        _, (hn, _) = self.lstm(x)
        return self.mlp(hn[-1])

# 10. Focal Loss
class FocalLoss(nn.Module):
    def __init__(self, gamma=2.0, alpha=0.8):
        super().__init__()
        self.gamma = gamma
        self.alpha = alpha

    def forward(self, inputs, targets):
        ce_loss = nn.CrossEntropyLoss(reduction='none')(inputs, targets)
        pt = torch.exp(-ce_loss)
        return (self.alpha * (1 - pt) ** self.gamma * ce_loss).mean()

# 11. Train
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = DeepLSTMClassifier(input_dim=X_combined.shape[-1]).to(device)
loss_fn = FocalLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

best_loss = float('inf')
patience = 10
no_improve = 0

for epoch in range(100):
    model.train()
    total_loss = 0
    for xb, yb in train_dl:
        xb, yb = xb.to(device), yb.to(device)
        pred = model(xb)
        loss = loss_fn(pred, yb)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    # Validation
    val_loss = 0
    model.eval()
    with torch.no_grad():
        for xb, yb in test_dl:
            xb, yb = xb.to(device), yb.to(device)
            pred = model(xb)
            loss = loss_fn(pred, yb)
            val_loss += loss.item()
    val_loss /= len(test_dl)

    print(f"Epoch {epoch+1:02d} | Train Loss: {total_loss:.4f} | Val Loss: {val_loss:.4f}")

    if val_loss < best_loss:
        best_loss = val_loss
        best_model_state = model.state_dict()
        no_improve = 0
    else:
        no_improve += 1
        if no_improve >= patience:
            print("⏹️ Early stopping triggered.")
            break

# Load best model
model.load_state_dict(best_model_state)
model.eval()

# 12. Evaluation
all_preds, all_labels = [], []
with torch.no_grad():
    for xb, yb in test_dl:
        xb = xb.to(device)
        preds = model(xb).argmax(dim=1).cpu().numpy()
        all_preds.extend(preds)
        all_labels.extend(yb.numpy())

print("\n📈 Accuracy:", accuracy_score(all_labels, all_preds))
print("\n📊 Classification Report:\n", classification_report(all_labels, all_preds))
print("\n🧱 Confusion Matrix:\n", confusion_matrix(all_labels, all_preds))
# Out:
# C:\Users\jhh33\anaconda3\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   warnings.warn(
# Epoch 01 | Train Loss: 15.6411 | Val Loss: 0.1352
# Epoch 02 | Train Loss: 11.7393 | Val Loss: 0.2596
# Epoch 03 | Train Loss: 8.3732 | Val Loss: 0.3408
# Epoch 04 | Train Loss: 6.4889 | Val Loss: 0.4450
# Epoch 05 | Train Loss: 5.2921 | Val Loss: 0.6433
# Epoch 06 | Train Loss: 4.5460 | Val Loss: 0.6905
# Epoch 07 | Train Loss: 3.9450 | Val Loss: 0.7545
# Epoch 08 | Train Loss: 3.7066 | Val Loss: 0.5245
# Epoch 09 | Train Loss: 3.2327 | Val Loss: 0.9912
# Epoch 10 | Train Loss: 2.2145 | Val Loss: 1.2055
# Epoch 11 | Train Loss: 1.7498 | Val Loss: 1.4031
# ⏹️ Early stopping triggered.
#
# 📈 Accuracy: 0.5668016194331984
#
# 📊 Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.53      0.38      0.44       449
#            1       0.58      0.72      0.65       539
#
#     accuracy                           0.57       988
#    macro avg       0.56      0.55      0.54       988
# weighted avg       0.56      0.57      0.55       988
#
#
# 🧱 Confusion Matrix:
#  [[171 278]
#  [150 389]]

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Dense, Concatenate, LayerNormalization, Dropout, MultiHeadAttention, GlobalAveragePooling1D
)
from tensorflow.keras.optimizers import Adam

# 1. Load data
df = pd.read_csv("news_stock_binary_classification.csv", parse_dates=["news_time"])
df["context"] = df["context"].astype(str)
df["company"] = df["company"].astype(str)

# 2. Split features
feature_cols_seq = [col for col in df.columns if col.startswith("x")]
feature_cols_finbert = ["finbert_positive", "finbert_neutral", "finbert_negative"]
company_dummies = pd.get_dummies(df["company"], prefix="company")
context_dummies = pd.get_dummies(df["context"], prefix="context")
X_static = pd.concat([df[feature_cols_finbert], company_dummies, context_dummies], axis=1).astype(np.float32).values
X_seq = df[feature_cols_seq].values
y = df["target"].values

# 3. Reshape sequence (batch, timesteps, features)
X_seq = X_seq.reshape((-1, 5, len(feature_cols_seq) // 5))

# 4. Normalize
scaler = StandardScaler()
X_seq_scaled = scaler.fit_transform(X_seq.reshape(-1, X_seq.shape[-1])).reshape(X_seq.shape)

# 5. TimeSeriesSplit
tscv = TimeSeriesSplit(n_splits=5)

for fold, (train_idx, test_idx) in enumerate(tscv.split(X_seq_scaled), 1):
    X_train_seq, X_test_seq = X_seq_scaled[train_idx], X_seq_scaled[test_idx]
    X_train_static, X_test_static = X_static[train_idx], X_static[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    tf.keras.backend.clear_session()
    tf.random.set_seed(42)
    np.random.seed(42)

    # Transformer Encoder Layer
    def transformer_encoder(inputs, num_heads=4, ff_dim=128, dropout=0.1):
        attn_output = MultiHeadAttention(num_heads=num_heads, key_dim=inputs.shape[-1])(inputs, inputs)
        attn_output = Dropout(dropout)(attn_output)
        out1 = LayerNormalization(epsilon=1e-6)(inputs + attn_output)

        ffn = tf.keras.Sequential([
            Dense(ff_dim, activation="relu"),
            Dense(inputs.shape[-1])
        ])
        ffn_output = ffn(out1)
        ffn_output = Dropout(dropout)(ffn_output)
        return LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

    # Model definition
    seq_input = Input(shape=(5, X_seq.shape[2]), name="seq_input")
    x = transformer_encoder(seq_input)
    x = GlobalAveragePooling1D()(x)

    static_input = Input(shape=(X_static.shape[1],), name="static_input")
    x = Concatenate()([x, static_input])
    x = Dense(128, activation="relu")(x)
    x = Dropout(0.3)(x)
    x = Dense(64, activation="relu")(x)
    output = Dense(1, activation="sigmoid")(x)

    model = Model(inputs=[seq_input, static_input], outputs=output)
    model.compile(loss="binary_crossentropy", optimizer=Adam(1e-3), metrics=["accuracy"])

    # Train
    model.fit([X_train_seq, X_train_static], y_train, epochs=30, batch_size=32, verbose=1)

    # Evaluate
    y_prob = model.predict([X_test_seq, X_test_static])
    y_pred = (y_prob.flatten() > 0.5).astype(int)

    print(f"\n📦 Fold {fold}")
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
    print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Epoch 1/30
# 26/26 [==============================] - 1s 2ms/step - loss: 0.6472 - accuracy: 0.6324
# Epoch 2/30
# 26/26 [==============================] - 0s 4ms/step - loss: 0.4855 - accuracy: 0.7860
# Epoch 3/30
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3417 - accuracy: 0.8452
# Epoch 4/30
# 26/26 [==============================] - 0s 2ms/step - loss: 0.2767 - accuracy: 0.8718
# Epoch 5/30
# 26/26 [==============================] - 0s 2ms/step - loss: 0.2467 - accuracy: 0.8694
# Epoch 6/30
# 26/26 [==============================] - 0s 2ms/step - loss: 0.2224 - accuracy: 0.9008
# Epoch 7/30
# 26/26 [==============================] - 0s 2ms/step - loss: 0.2490 - accuracy: 0.8912
# Epoch 8/30
# 26/26 [==============================] - 0s 2ms/step - loss: 0.2127 - accuracy: 0.9057
# Epoch 9/30
# 26/26 [==============================] - 0s 2ms/step - loss: 0.1817 - accuracy: 0.9154
# Epoch 10/30
# 26/26 [==============================] - 0s 2ms/step - loss: 0.1725 - accuracy: 0.9262
# Epoch 11/30
# 26/26 [==============================] - 0s 2ms/step - loss: 0.1351 - accuracy: 0.9383
# Epoch 12/30
# 26/26 [==============================] - 0s 2ms/step - loss: 0.1337 - accuracy: 0.9371
# Epoch 13/30
# 26/26 [==============================] - 0s 2ms/step - loss: 0.1034 - accuracy: 0.9565
# Epoch 14/30
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0924 - accuracy: 0.9589
# Epoch 15/30
# 26/26 [==============================] - 0s 2ms/step - loss: 0.1009 - accuracy: 0.9601
# Epoch 16/30
# 26/26 [==============================] - 0s 2ms/step - loss: 0.1128 - accuracy: 0.9577
# Epoch 17/30
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0874 - accuracy: 0.9637
# Epoch 18/30
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0837 - accuracy: 0.9613
# Epoch 19/30
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0631 - accuracy: 0.9794
# Epoch 20/30
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0481 - accuracy: 0.9843
# Epoch 21/30
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0458 - accuracy: 0.9831
# Epoch 22/30
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0541 - accuracy: 0.9794
# Epoch 23/30
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0436 - accuracy: 0.9855
# Epoch 24/30
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0546 - accuracy: 0.9794
# Epoch 25/30
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0455 - accuracy: 0.9891
# Epoch 26/30
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0304 - accuracy: 0.9891
# Epoch 27/30
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0298 - accuracy: 0.9903
# Epoch 28/30
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0297 - accuracy: 0.9879
# Epoch 29/30
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0550 - accuracy: 0.9794
# Epoch 30/30
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0567 - accuracy: 0.9770
# 26/26 [==============================] - 0s 920us/step
#
# 📦 Fold 1
# Accuracy: 0.5121359223300971
# Confusion Matrix:
#  [[121 318]
#  [ 84 301]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.59      0.28      0.38       439
#            1       0.49      0.78      0.60       385
#
#     accuracy                           0.51       824
#    macro avg       0.54      0.53      0.49       824
# weighted avg       0.54      0.51      0.48       824
#
# Epoch 1/30
# 52/52 [==============================] - 1s 2ms/step - loss: 0.6311 - accuracy: 0.6475
# Epoch 2/30
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5127 - accuracy: 0.7553
# Epoch 3/30
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3974 - accuracy: 0.8050
# Epoch 4/30
# 52/52 [==============================] - 0s 2ms/step - loss: 0.3308 - accuracy: 0.8401
# Epoch 5/30
# 52/52 [==============================] - 0s 2ms/step - loss: 0.2845 - accuracy: 0.8613
# Epoch 6/30
# 52/52 [==============================] - 0s 2ms/step - loss: 0.2432 - accuracy: 0.8898
# Epoch 7/30
# 52/52 [==============================] - 0s 2ms/step - loss: 0.2656 - accuracy: 0.8813
# Epoch 8/30
# 52/52 [==============================] - 0s 2ms/step - loss: 0.2097 - accuracy: 0.9043
# Epoch 9/30
# 52/52 [==============================] - 0s 2ms/step - loss: 0.1861 - accuracy: 0.9098
# Epoch 10/30
# 52/52 [==============================] - 0s 2ms/step - loss: 0.1635 - accuracy: 0.9231
# Epoch 11/30
# 52/52 [==============================] - 0s 2ms/step - loss: 0.1681 - accuracy: 0.9207
# Epoch 12/30
# 52/52 [==============================] - 0s 2ms/step - loss: 0.1405 - accuracy: 0.9449
# Epoch 13/30
# 52/52 [==============================] - 0s 2ms/step - loss: 0.1315 - accuracy: 0.9443
# Epoch 14/30
# 52/52 [==============================] - 0s 2ms/step - loss: 0.1147 - accuracy: 0.9491
# Epoch 15/30
# 52/52 [==============================] - 0s 2ms/step - loss: 0.1123 - accuracy: 0.9528
# Epoch 16/30
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0852 - accuracy: 0.9661
# Epoch 17/30
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0788 - accuracy: 0.9679
# Epoch 18/30
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0812 - accuracy: 0.9661
# Epoch 19/30
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0954 - accuracy: 0.9624
# Epoch 20/30
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0904 - accuracy: 0.9624
# Epoch 21/30
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0874 - accuracy: 0.9685
# Epoch 22/30
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0640 - accuracy: 0.9794
# Epoch 23/30
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0538 - accuracy: 0.9824
# Epoch 24/30
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0556 - accuracy: 0.9758
# Epoch 25/30
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0494 - accuracy: 0.9818
# Epoch 26/30
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0429 - accuracy: 0.9818
# Epoch 27/30
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0498 - accuracy: 0.9824
# Epoch 28/30
# 52/52 [==============================] - 0s 2ms/step - loss: 0.1144 - accuracy: 0.9552
# Epoch 29/30
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0572 - accuracy: 0.9794
# Epoch 30/30
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0432 - accuracy: 0.9818
# 26/26 [==============================] - 0s 920us/step
#
# 📦 Fold 2
# Accuracy: 0.5946601941747572
# Confusion Matrix:
#  [[400  16]
#  [318  90]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.56      0.96      0.71       416
#            1       0.85      0.22      0.35       408
#
#     accuracy                           0.59       824
#    macro avg       0.70      0.59      0.53       824
# weighted avg       0.70      0.59      0.53       824
#
# Epoch 1/30
# 78/78 [==============================] - 2s 2ms/step - loss: nan - accuracy: 0.5503
# Epoch 2/30
# 78/78 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5143
# Epoch 3/30
# 78/78 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5143
# Epoch 4/30
# 78/78 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5143
# Epoch 5/30
# 78/78 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5143
# Epoch 6/30
# 78/78 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5143
# Epoch 7/30
# 78/78 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5143
# Epoch 8/30
# 78/78 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5143
# Epoch 9/30
# 78/78 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5143
# Epoch 10/30
# 78/78 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5143
# Epoch 11/30
# 78/78 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5143
# Epoch 12/30
# 78/78 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5143
# Epoch 13/30
# 78/78 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5143
# Epoch 14/30
# 78/78 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5143
# Epoch 15/30
# 78/78 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5143
# Epoch 16/30
# 78/78 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5143
# Epoch 17/30
# 78/78 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5143
# Epoch 18/30
# 78/78 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5143
# Epoch 19/30
# 78/78 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5143
# Epoch 20/30
# 78/78 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5143
# Epoch 21/30
# 78/78 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5143
# Epoch 22/30
# 78/78 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5143
# Epoch 23/30
# 78/78 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5143
# Epoch 24/30
# 78/78 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5143
# Epoch 25/30
# 78/78 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5143
# Epoch 26/30
# 78/78 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5143
# Epoch 27/30
# 78/78 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5143
# Epoch 28/30
# 78/78 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5143
# Epoch 29/30
# 78/78 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5143
# Epoch 30/30
# 78/78 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5143
# 26/26 [==============================] - 0s 920us/step
#
# 📦 Fold 3
# Accuracy: 0.5533980582524272
# Confusion Matrix:
#  [[456   0]
#  [368   0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.55      1.00      0.71       456
#            1       0.00      0.00      0.00       368
#
#     accuracy                           0.55       824
#    macro avg       0.28      0.50      0.36       824
# weighted avg       0.31      0.55      0.39       824
#
# Epoch 1/30
# c:\Users\jhh33\anaconda3\envs\pythonProject1\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\jhh33\anaconda3\envs\pythonProject1\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\jhh33\anaconda3\envs\pythonProject1\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 104/104 [==============================] - 1s 2ms/step - loss: nan - accuracy: 0.5308
# Epoch 2/30
# 104/104 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5241
# Epoch 3/30
# 104/104 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5241
# Epoch 4/30
# 104/104 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5241
# Epoch 5/30
# 104/104 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5241
# Epoch 6/30
# 104/104 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5241
# Epoch 7/30
# 104/104 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5241
# Epoch 8/30
# 104/104 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5241
# Epoch 9/30
# 104/104 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5241
# Epoch 10/30
# 104/104 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5241
# Epoch 11/30
# 104/104 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5241
# Epoch 12/30
# 104/104 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5241
# Epoch 13/30
# 104/104 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5241
# Epoch 14/30
# 104/104 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5241
# Epoch 15/30
# 104/104 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5241
# Epoch 16/30
# 104/104 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5241
# Epoch 17/30
# 104/104 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5241
# Epoch 18/30
# 104/104 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5241
# Epoch 19/30
# 104/104 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5241
# Epoch 20/30
# 104/104 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5241
# Epoch 21/30
# 104/104 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5241
# Epoch 22/30
# 104/104 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5241
# Epoch 23/30
# 104/104 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5241
# Epoch 24/30
# 104/104 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5241
# Epoch 25/30
# 104/104 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5241
# Epoch 26/30
# 104/104 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5241
# Epoch 27/30
# 104/104 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5241
# Epoch 28/30
# 104/104 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5241
# Epoch 29/30
# 104/104 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5241
# Epoch 30/30
# 104/104 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.5241
# 26/26 [==============================] - 0s 920us/step
#
# 📦 Fold 4
# Accuracy: 0.3580097087378641
# Confusion Matrix:
#  [[295   0]
#  [529   0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.36      1.00      0.53       295
#            1       0.00      0.00      0.00       529
#
#     accuracy                           0.36       824
#    macro avg       0.18      0.50      0.26       824
# weighted avg       0.13      0.36      0.19       824
#
# Epoch 1/30
# c:\Users\jhh33\anaconda3\envs\pythonProject1\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\jhh33\anaconda3\envs\pythonProject1\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\jhh33\anaconda3\envs\pythonProject1\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 129/129 [==============================] - 1s 2ms/step - loss: nan - accuracy: 0.4902
# Epoch 2/30
# 129/129 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.4909
# Epoch 3/30
# 129/129 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.4909
# Epoch 4/30
# 129/129 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.4909
# Epoch 5/30
# 129/129 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.4909
# Epoch 6/30
# 129/129 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.4909
# Epoch 7/30
# 129/129 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.4909
# Epoch 8/30
# 129/129 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.4909
# Epoch 9/30
# 129/129 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.4909
# Epoch 10/30
# 129/129 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.4909
# Epoch 11/30
# 129/129 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.4909
# Epoch 12/30
# 129/129 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.4909
# Epoch 13/30
# 129/129 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.4909
# Epoch 14/30
# 129/129 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.4909
# Epoch 15/30
# 129/129 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.4909
# Epoch 16/30
# 129/129 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.4909
# Epoch 17/30
# 129/129 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.4909
# Epoch 18/30
# 129/129 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.4909
# Epoch 19/30
# 129/129 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.4909
# Epoch 20/30
# 129/129 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.4909
# Epoch 21/30
# 129/129 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.4909
# Epoch 22/30
# 129/129 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.4909
# Epoch 23/30
# 129/129 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.4909
# Epoch 24/30
# 129/129 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.4909
# Epoch 25/30
# 129/129 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.4909
# Epoch 26/30
# 129/129 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.4909
# Epoch 27/30
# 129/129 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.4909
# Epoch 28/30
# 129/129 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.4909
# Epoch 29/30
# 129/129 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.4909
# Epoch 30/30
# 129/129 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.4909
# 26/26 [==============================] - 0s 960us/step
#
# 📦 Fold 5
# Accuracy: 0.49029126213592233
# Confusion Matrix:
#  [[404   0]
#  [420   0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.49      1.00      0.66       404
#            1       0.00      0.00      0.00       420
#
#     accuracy                           0.49       824
#    macro avg       0.25      0.50      0.33       824
# weighted avg       0.24      0.49      0.32       824
# c:\Users\jhh33\anaconda3\envs\pythonProject1\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\jhh33\anaconda3\envs\pythonProject1\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\jhh33\anaconda3\envs\pythonProject1\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
